# %%
import numpy as np
from pylab import gca
import numpy as np
import math
from tqdm import tqdm
import torch
import torchvision
import torch.nn as nn
from torch.utils import data
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import torchvision.transforms.functional as TF
from torch.optim import lr_scheduler
import time
import os
import cv2
import pdb
from PIL import Image
import matplotlib.pyplot as plt

# %%
def frame_tick(frame_width = 2, tick_width = 1.5):
    ax = gca()
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(frame_width)
    plt.tick_params(direction = 'in', 
                    width = tick_width)
def legend(location = 'best', fontsize = 8):
        plt.legend(loc = location, fontsize = fontsize, frameon = False)

# %%
parent_directory = '/home/oogoke/SRdataset/epoch_srdiff_attempt_5_add_embed_mean_corrected_5eneg5/'
epoch = 148
data_1 = np.load(os.path.join(parent_directory, 'all_data-{}.npz').format(epoch))

# %%
data_1.files
# Out:
# ['res',
#  'hr',
#  'true_lr',
#  'upscaled_lr',
#  'sampled',
#  'mean_lrs',
#  'std_lrs',
#  'mean_resid',
#  'std_resid']

# %%
std_resid = data_1['std_resid']
mean_resid = data_1['mean_resid']
std_lrs = data_1['std_lrs']
mean_lrs = data_1['mean_lrs']
sampled_data = data_1['sampled']
lr_data = data_1['upscaled_lr']
input_data = data_1['true_lr']
residuals = sampled_data[:,0]*std_resid + mean_resid

true_residual = data_1['res']*std_resid + mean_resid
true_lrs = input_data*std_lrs + mean_lrs
hr = data_1['hr']

# %%
plt.imshow(data_1['upscaled_lr'][0])
plt.show()
plt.imshow(data_1['true_lr'][0])
plt.show()
plt.imshow(data_1['hr'][0])
plt.show()
plt.imshow(data_1['res'][0])
plt.show()
for i in range(16):
    plt.title(i)
    plt.imshow(data_1['sampled'][i,0])
    plt.show()

# %%
def plot_temp_images_srdiff(data, max_temp = 5000, min_temp = 293, dpi = 90, scaling_factor = 1.5, method = 'Lanczos'):
# max_temp = 5000
# min_temp = 293
# dpi = 90
# scaling_factor = 1.5
# method = 'Lanczos'

    std_resid = data['std_resid']
    mean_resid = data['mean_resid']
    std_lrs = data['std_lrs']
    mean_lrs = data['mean_lrs']
    sampled_data = data['sampled']
    lr_data = data['upscaled_lr']
    input_data = data['true_lr']
    residuals = sampled_data[:,0]*std_resid + mean_resid

    true_residual = data['res']*std_resid + mean_resid
    true_lrs = input_data*std_lrs + mean_lrs
    hr = data['hr']
    plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
    plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])

    plt.xlabel(r'x $[\mu m]$')
    plt.ylabel(r'z $[\mu m]$')
    clb = plt.colorbar()
    clb.ax.set_title(r'T$[K]$',fontsize=10)
    frame_tick()
    plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
    plt.show()
    plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)

    plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])

    plt.xlabel(r'x $[\mu m]$')
    plt.ylabel(r'z $[\mu m]$')
    clb = plt.colorbar()
    clb.ax.set_title(r'T$[K]$',fontsize=10)
    frame_tick()
    plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
    plt.show()


    plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)

    plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])

    plt.xlabel(r'x $[\mu m]$')
    plt.ylabel(r'z $[\mu m]$')
    clb = plt.colorbar()
    clb.ax.set_title(r'T$[K]$',fontsize=10)
    frame_tick()
    plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
    plt.show()
    plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)

    plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])

    plt.xlabel(r'x $[\mu m]$')
    plt.ylabel(r'z $[\mu m]$')
    clb = plt.colorbar()
    clb.ax.set_title(r'T$[K]$',fontsize=10)
    frame_tick()
    plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
    plt.show()

# %%
def plot_temp_lines_srdiff(data, max_temp = 5000, min_temp = 293, dpi = 90, scaling_factor = 1.5, method = 'Lanczos'):

    std_resid = data_1['std_resid']
    mean_resid = data_1['mean_resid']
    std_lrs = data_1['std_lrs']
    mean_lrs = data_1['mean_lrs']
    sampled_data = data_1['sampled']
    lr_data = data_1['upscaled_lr']
    input_data = data_1['true_lr']
    residuals = sampled_data[:,0]*std_resid + mean_resid

    true_residual = data_1['res']*std_resid + mean_resid
    true_lrs = input_data*std_lrs + mean_lrs
    hr = data_1['hr']
    generated_hr = lr_data + residuals
    # dpi = 150
    # scaling_factor = 1.5
    plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)

    plt.title(r'SRDiff model, Cross section: x = 200 $\mu m$')
    plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
    plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input') 
    plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
    legend()
    plt.ylabel(r'$T [K]$')
    plt.xlabel(r'$z [\mu m$]')
    frame_tick()
    plt.ylim(min_temp, max_temp)
    plt.xlim(0, 400)
    plt.show()

# %%
def get_keyhole_profile(image, ):
    image = image[0].T
    binarized = image > 1900
    profile = []
    dim = image.shape[-1]
    for i in range(dim):
        coords = np.where(binarized[:,i])[0]
        if len(coords) > 0:

#             print(len(coords), coords)
            profile.append(np.max(coords))
        else:
            profile.append(dim)
    profile = np.array(profile)
    profile[profile< 5] = dim
#     print(np.min(profile))
    return(profile)

def get_mp_profile(image, ):
    image = image[0].T
    binarized = image > 1900
    profile = []
    dim = image.shape[-1]
    for i in range(dim):
        coords = np.where(binarized[:,i])[0]
        if len(coords) > 0:

#             print(len(coords), coords)
            profile.append(np.min(coords))
        else:
            profile.append(dim)
    profile = np.array(profile)
    profile[profile< 5] = dim
#     print(np.min(profile))
    return(profile)

# %%
def plot_srdiff_contours(data, max_temp = 5000, min_temp = 293, dpi = 90, scaling_factor = 1.5, method = 'Lanczos', split = 'Train'):
    std_resid = data['std_resid']
    mean_resid = data['mean_resid']
    std_lrs = data['std_lrs']
    mean_lrs = data['mean_lrs']
    sampled_data = data['sampled']
    lr_data = data['upscaled_lr']
    input_data = data['true_lr']
    

    residuals = sampled_data[:,0]*std_resid + mean_resid
    generated_hr = lr_data + residuals
    true_residual = data['res']*std_resid + mean_resid
    true_lrs = input_data*std_lrs + mean_lrs
    hr = data['hr']
    profile = get_keyhole_profile(generated_hr)
    profile_gt = get_keyhole_profile(hr)
    profile_input = get_keyhole_profile(true_lrs)
    plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
    plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
    plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
    plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
    frame_tick()
    plt.ylim([-300,0])
    legend()
    plt.title('[{} Data] Keyhole Depth'.format('Train'), fontsize = 10)
    plt.xlabel(r'x [$\mu m$] ')
    plt.ylabel(r'z [$\mu m$] ')


    profile = get_mp_profile(generated_hr)
    profile_gt = get_mp_profile(hr)
    profile_input = get_mp_profile(true_lrs)
    plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
    plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
    plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
    plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
    frame_tick()
    plt.ylim([-300,0])
    legend()
    plt.title('[{} Data] Melt Pool Depth'.format(split), fontsize = 10)
    plt.xlabel(r'x [$\mu m$] ')
    plt.ylabel(r'z [$\mu m$] ')

# %%
def plot_temp_images_srdiff(data, max_temp = 5000, min_temp = 293, dpi = 90, scaling_factor = 1.5, method = 'Lanczos'):

# %%
for epoch in range(140, 150, 2):
    parent_directory = '/home/oogoke/SRdataset/epoch_srdiff_attempt_5_add_embed_mean_corrected_5eneg5/'
    data_1 = np.load(os.path.join(parent_directory, 'all_data-{}.npz').format(epoch))
    plot_temp_images_srdiff(data_1)
    plot_temp_lines_srdiff(data_1)
    plot_srdiff_contours(data_1)

# %%
# %history
# Out:
# import numpy as np
# from pylab import gca
# import numpy as np
# import math
# from tqdm import tqdm
# import torch
# import torchvision
# import torch.nn as nn
# from torch.utils import data
# from torchvision import transforms
# from torchvision.utils import save_image
# from torchvision.datasets import MNIST
# import torchvision.transforms.functional as TF
# from torch.optim import lr_scheduler
# import time
# import os
# import cv2
# import pdb
# from PIL import Image
# import matplotlib.pyplot as plt
# def frame_tick(frame_width = 2, tick_width = 1.5):
#     ax = gca()
#     for axis in ['top','bottom','left','right']:
#         ax.spines[axis].set_linewidth(frame_width)
#     plt.tick_params(direction = 'in',
#                     width = tick_width)
# def legend(location = 'best', fontsize = 8):
#         plt.legend(loc = location, fontsize = fontsize, frameon = False)
# data_1 = np.load('/home/oogoke/SRdataset/epoch_srdiff_attempt_5_add_embed_mean_corrected_5eneg5/all_data-148.npz')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# sampled_data = data_1['sampled']
# img = sampled_data[0,0]*std_resid + mean_resid
#
# plt.imshow(img.T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# data_1.files
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# sampled_data = data_1['sampled']
# lr_data = data_1['true_lr']
# img = sampled_data[0,0]*std_resid + mean_resid
# plt.imshow(lr_data)
# plt.imshow(lr_data[0,0])
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# img = sampled_data[0,0]*std_resid + mean_resid
# plt.imshow(lr_data[0])
#
# plt.imshow(img.T + lr_data[0].T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# data_1['upscaled_lr']
# plt.imshow(data_1['upscaled_lr'])
# plt.imshow(data_1['upscaled_lr'][0])
# plt.imshow(data_1['upscaled_lr'][0])
# plt.imshow(data_1['true_lr'][0])
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0,0])
# plt.show()
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0])
# plt.show()
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0])
# plt.show()
# plt.imshow(data_1['sampled'][0,0])
# plt.show()
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0])
# plt.show()
# plt.imshow(data_1['sampled'][1,0])
# plt.show()
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0])
# plt.show()
# for i in range(16):
#     plt.imshow(data_1['sampled'][i,0])
#     plt.show()
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0])
# plt.show()
# for i in range(16):
#     plt.title(i)
#     plt.imshow(data_1['sampled'][i,0])
#     plt.show()
# data_1 = np.load('/home/oogoke/SRdataset/epoch_srdiff_attempt_5_add_embed_mean_corrected_5eneg5/all_data-146.npz')
# data_1.files
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# img = sampled_data[0,0]*std_resid + mean_resid
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0])
# plt.show()
# for i in range(16):
#     plt.title(i)
#     plt.imshow(data_1['sampled'][i,0])
#     plt.show()
# data_1 = np.load('/home/oogoke/SRdataset/epoch_srdiff_attempt_5_add_embed_mean_corrected_5eneg5/all_data-146.npz')
# data_1.files
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# img = sampled_data[0,0]*std_resid + mean_resid
# plt.imshow(data_1['upscaled_lr'][0])
# plt.show()
# plt.imshow(data_1['true_lr'][0])
# plt.show()
# plt.imshow(data_1['hr'][0])
# plt.show()
# plt.imshow(data_1['res'][0])
# plt.show()
# for i in range(16):
#     plt.title(i)
#     plt.imshow(data_1['sampled'][i,0])
#     plt.show()
#
# plt.imshow(img.T + lr_data[0].T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
#
# plt.imshow(lr_data[0].T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
#
# plt.imshow(true_lr[0].T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
#
# plt.imshow(data_1['true_lr'][0].T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
#
# plt.imshow((data_1['true_lr'][0]*data_1['std_lrs'] + data_1['mean_lrs']).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
#
# plt.imshow((data_1['true_lr'][0]*data_1['std_lrs'] + data_1['mean_lrs']).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
#
# img = sampled_data[:,0]*std_resid + mean_resid
# plt.imshow(img[0])
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
# true_lrs = input_data[:,0]*std_lrs + mean_lrs
# plt.imshow(true_lrs[0])
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
# true_lrs = input_data[0,0]*std_lrs + mean_lrs
# plt.imshow(true_lrs)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
# true_lrs = input_data[:,0]*std_lrs + mean_lrs
# plt.imshow(true_lrs)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# plt.imshow(true_lrs[0])
# true_lrs.shape
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = 300, vmax=8000, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# method = 'lanczos'
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# method = 'Lanczos'
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# method = 'Lanczos'
# plt.figure(dpi = 150)
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# method = 'Lanczos'
# plt.figure(dpi = 90, size = [4,3])
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# method = 'Lanczos'
# plt.figure(dpi = 90, figsize = [4,3])
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# method = 'Lanczos'
# plt.figure(dpi = 150, figsize = [4,3])
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# method = 'Lanczos'
# plt.figure(dpi = 90, figsize = np.array([4,3])*1.5)
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# max_temp = 5000
# min_temp = 293
# dpi = 90
# scaling_factor = 1.5
# method = 'Lanczos'
# plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
# plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
# plt.show()
# plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
# plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.show()
#
#
# plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
# plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
# plt.show()
# plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
# plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
# plt.xlabel(r'x $[\mu m]$')
# plt.ylabel(r'z $[\mu m]$')
# clb = plt.colorbar()
# clb.ax.set_title(r'T$[K]$',fontsize=10)
# frame_tick()
# plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
# plt.show()
# def plot_temp_images(data, max_temp = 5000, min_temp = 293, dpi = 90, scaling_factor = 1.5, method = 'Lanczos')
# # max_temp = 5000
# # min_temp = 293
# # dpi = 90
# # scaling_factor = 1.5
# # method = 'Lanczos'
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#     plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
#     plt.show()
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
#     plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
#     plt.show()
#
#
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
#     plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
#     plt.show()
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
#     plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
#     plt.show()
# def plot_temp_images(data, max_temp = 5000, min_temp = 293, dpi = 90, scaling_factor = 1.5, method = 'Lanczos'):
# # max_temp = 5000
# # min_temp = 293
# # dpi = 90
# # scaling_factor = 1.5
# # method = 'Lanczos'
#
#     std_resid = data['std_resid']
#     mean_resid = data['mean_resid']
#     std_lrs = data['std_lrs']
#     mean_lrs = data['mean_lrs']
#     sampled_data = data['sampled']
#     lr_data = data['upscaled_lr']
#     input_data = data['true_lr']
#     residuals = sampled_data[:,0]*std_resid + mean_resid
#
#     true_residual = data['res']*std_resid + mean_resid
#     true_lrs = input_data*std_lrs + mean_lrs
#     hr = data['hr']
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#     plt.imshow((true_lrs[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] Low Resolution, {} downscaling'.format('Train', method), fontsize = 10)
#     plt.show()
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
#     plt.imshow((hr[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
#     plt.show()
#
#
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
#     plt.imshow((residuals[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] Residual Between HR and LR, Sampled'.format('Train'), fontsize = 10)
#     plt.show()
#     plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
#     plt.imshow((true_residual[0]).T, cmap = 'jet', vmin = min_temp, vmax=max_temp, origin = 'lower',  extent=[0*5,80*5,0*5,80*5])
#
#     plt.xlabel(r'x $[\mu m]$')
#     plt.ylabel(r'z $[\mu m]$')
#     clb = plt.colorbar()
#     clb.ax.set_title(r'T$[K]$',fontsize=10)
#     frame_tick()
#     plt.title('[{} Data] Residual Between HR and LR, GT'.format('Train'), fontsize = 10)
#     plt.show()
# parent_directory = '/home/oogoke/SRdataset/epoch_srdiff_attempt_5_add_embed_mean_corrected_5eneg5/'
# data_1 = np.load(os.path.join(parent_directory, 'all_data-146.npz'))
# plot_temp_images(data_1)
# for epoch in range(140, 150, 2):
#     parent_directory = '/home/oogoke/SRdataset/epoch_srdiff_attempt_5_add_embed_mean_corrected_5eneg5/'
#     data_1 = np.load(os.path.join(parent_directory, 'all_data-{}.npz').format(epoch))
#     plot_temp_images(data_1)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*20*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][0][10,:].cpu().numpy(),label = 'Low-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),target[0][0][40,:].cpu().numpy(), label = 'High-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),new_out[0][0][40,:].cpu().detach().numpy(), label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*20*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:].cpu().numpy(),label = 'Low-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),target[0][0][40,:].cpu().numpy(), label = 'High-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),new_out[0][0][40,:].cpu().detach().numpy(), label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# true_lrs.shape
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*20*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),target[0][0][40,:].cpu().numpy(), label = 'High-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),new_out[0][0][40,:].cpu().detach().numpy(), label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*20*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][0][40,:], label = 'High-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),new_out[0][0][40,:].cpu().detach().numpy(), label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*20*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),new_out[0][0][40,:].cpu().detach().numpy(), label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
#
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# # plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),new_out[0][0][40,:].cpu().detach().numpy(), label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = true_lrs + true_residual
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:].cpu().detach().numpy(), label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = lr_data + true_residual
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = lr_data + residuals
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = lr_data + residuals
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# frame_tick()
# plt.ylim(293, 5000)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = lr_data + residuals
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# frame_tick()
# plt.ylim(293, 5000)
# plt.xlim(0, 400)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = lr_data + residuals
# dpi = 90
# scaling_factor = 1.5
# plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
# plt.title(r'Cross section: x = 200 $\mu m$', fontsize = 10)
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# frame_tick()
# plt.ylim(293, 5000)
# plt.xlim(0, 400)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = lr_data + residuals
# dpi = 150
# scaling_factor = 1.5
# plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
# plt.title(r'Cross section: x = 200 $\mu m$')
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
# legend()
# plt.ylabel(r'T [K]')
# plt.xlabel(r'z [$\mu m$]')
# frame_tick()
# plt.ylim(293, 5000)
# plt.xlim(0, 400)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# generated_hr = lr_data + residuals
# dpi = 150
# scaling_factor = 1.5
# plt.figure(dpi = dpi, figsize = np.array([4,3])*scaling_factor)
#
# plt.title(r'Cross section: x = 200 $\mu m$')
# plt.plot(80*5*(np.arange(true_lrs.shape[2])/true_lrs.shape[2]),true_lrs[0][10,:],label = 'Low-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),hr[0][40,:], label = 'High-Resolution Input')
# plt.plot(80*5*(np.arange(hr.shape[2])/hr.shape[2]),generated_hr[0][40,:], label = 'Output')
# legend()
# plt.ylabel(r'$T [K]$')
# plt.xlabel(r'z [$\mu m$]')
# frame_tick()
# plt.ylim(293, 5000)
# plt.xlim(0, 400)
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# ...
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# max_depth = []
# max_depth_gt = []
# max_depth_input = []
#
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# generated_hr = lr_data + residuals
#
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# profile = get_profile(generated_hr)
# profile_gt = get_profile(hr)
# profile_input = get_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mu$ m] ')
# max_depth.append(5*(80-np.min(profile)))
# max_depth_gt.append(5*(80-np.min(profile_gt)))
# max_depth_input.append(5*(80-np.min(profile_input)))
# def get_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# max_depth = []
# max_depth_gt = []
# max_depth_input = []
#
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# generated_hr = lr_data + residuals
#
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# profile = get_profile(generated_hr)
# profile_gt = get_profile(hr)
# profile_input = get_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mum$] ')
# plt.ylabel(r'z [$\mum$] ')
#
# max_depth.append(5*(80-np.min(profile)))
# max_depth_gt.append(5*(80-np.min(profile_gt)))
# max_depth_input.append(5*(80-np.min(profile_input)))
# def get_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# max_depth = []
# max_depth_gt = []
# max_depth_input = []
#
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# generated_hr = lr_data + residuals
#
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# profile = get_profile(generated_hr)
# profile_gt = get_profile(hr)
# profile_input = get_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] High Resolution'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mu m$] ')
# plt.ylabel(r'z [$\mu m$] ')
#
# max_depth.append(5*(80-np.min(profile)))
# max_depth_gt.append(5*(80-np.min(profile_gt)))
# max_depth_input.append(5*(80-np.min(profile_input)))
# def get_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# max_depth = []
# max_depth_gt = []
# max_depth_input = []
#
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# generated_hr = lr_data + residuals
#
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# profile = get_profile(generated_hr)
# profile_gt = get_profile(hr)
# profile_input = get_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] Keyhole Depth'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mu m$] ')
# plt.ylabel(r'z [$\mu m$] ')
#
# max_depth.append(5*(80-np.min(profile)))
# max_depth_gt.append(5*(80-np.min(profile_gt)))
# max_depth_input.append(5*(80-np.min(profile_input)))
# def get_keyhole_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# def get_mp_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.min(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
#
# max_depth = []
# max_depth_gt = []
# max_depth_input = []
#
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# generated_hr = lr_data + residuals
#
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# profile = get_keyhole_profile(generated_hr)
# profile_gt = get_keyhole_profile(hr)
# profile_input = get_keyhole_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] Keyhole Depth'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mu m$] ')
# plt.ylabel(r'z [$\mu m$] ')
#
#
# profile = get_mp_profile(generated_hr)
# profile_gt = get_mp_profile(hr)
# profile_input = get_mp_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] Keyhole Depth'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mu m$] ')
# plt.ylabel(r'z [$\mu m$] ')
# max_depth.append(5*(80-np.min(profile)))
# max_depth_gt.append(5*(80-np.min(profile_gt)))
# max_depth_input.append(5*(80-np.min(profile_input)))
# def get_keyhole_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# def get_mp_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.min(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
#
# max_depth = []
# max_depth_gt = []
# max_depth_input = []
#
# std_resid = data_1['std_resid']
# mean_resid = data_1['mean_resid']
# std_lrs = data_1['std_lrs']
# mean_lrs = data_1['mean_lrs']
# sampled_data = data_1['sampled']
# lr_data = data_1['upscaled_lr']
# input_data = data_1['true_lr']
# generated_hr = lr_data + residuals
#
# residuals = sampled_data[:,0]*std_resid + mean_resid
#
# true_residual = data_1['res']*std_resid + mean_resid
# true_lrs = input_data*std_lrs + mean_lrs
# hr = data_1['hr']
# profile = get_keyhole_profile(generated_hr)
# profile_gt = get_keyhole_profile(hr)
# profile_input = get_keyhole_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] Keyhole Depth'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mu m$] ')
# plt.ylabel(r'z [$\mu m$] ')
#
#
# profile = get_mp_profile(generated_hr)
# profile_gt = get_mp_profile(hr)
# profile_input = get_mp_profile(true_lrs)
# plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
# plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
# plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
# plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
# frame_tick()
# plt.ylim([-300,0])
# legend()
# plt.title('[{} Data] Melt Pool Depth'.format('Train'), fontsize = 10)
# plt.xlabel(r'x [$\mu m$] ')
# plt.ylabel(r'z [$\mu m$] ')
# max_depth.append(5*(80-np.min(profile)))
# max_depth_gt.append(5*(80-np.min(profile_gt)))
# max_depth_input.append(5*(80-np.min(profile_input)))
# def get_keyhole_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# def get_mp_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.min(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
#
# max_depth = []
# max_depth_gt = []
# max_depth_input = []
# def plot_srdiff_contours(data, max_temp = 5000, min_temp = 293, dpi = 90, scaling_factor = 1.5, method = 'Lanczos', split = 'Train'):
#     std_resid = data['std_resid']
#     mean_resid = data['mean_resid']
#     std_lrs = data['std_lrs']
#     mean_lrs = data['mean_lrs']
#     sampled_data = data['sampled']
#     lr_data = data['upscaled_lr']
#     input_data = data['true_lr']
#     generated_hr = lr_data + residuals
#
#     residuals = sampled_data[:,0]*std_resid + mean_resid
#
#     true_residual = data['res']*std_resid + mean_resid
#     true_lrs = input_data*std_lrs + mean_lrs
#     hr = data['hr']
#     profile = get_keyhole_profile(generated_hr)
#     profile_gt = get_keyhole_profile(hr)
#     profile_input = get_keyhole_profile(true_lrs)
#     plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
#     plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
#     plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
#     plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
#     frame_tick()
#     plt.ylim([-300,0])
#     legend()
#     plt.title('[{} Data] Keyhole Depth'.format('Train'), fontsize = 10)
#     plt.xlabel(r'x [$\mu m$] ')
#     plt.ylabel(r'z [$\mu m$] ')
#
#
#     profile = get_mp_profile(generated_hr)
#     profile_gt = get_mp_profile(hr)
#     profile_input = get_mp_profile(true_lrs)
#     plt.figure(dpi = 150, figsize = np.array([4,3])*1.25)
#     plt.plot(20*np.arange(20),profile_input*20 - 400, '--', label = 'Low Resolution (Input)')
#     plt.plot(5*np.arange(80),profile*5 - 400, label = 'Super Resolution (Output)' )
#     plt.plot(5*np.arange(80),profile_gt*5 - 400, 'k', linewidth = 2.0, label = 'High Resolution')
#     frame_tick()
#     plt.ylim([-300,0])
#     legend()
#     plt.title('[{} Data] Melt Pool Depth'.format(split), fontsize = 10)
#     plt.xlabel(r'x [$\mu m$] ')
#     plt.ylabel(r'z [$\mu m$] ')
#     max_depth.append(5*(80-np.min(profile)))
#     max_depth_gt.append(5*(80-np.min(profile_gt)))
#     max_depth_input.append(5*(80-np.min(profile_input)))
# def get_keyhole_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.max(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
#
# def get_mp_profile(image, ):
#     image = image[0].T
#     binarized = image > 1900
#     profile = []
#     dim = image.shape[-1]
#     for i in range(dim):
#         coords = np.where(binarized[:,i])[0]
#         if len(coords) > 0:
#
# #             print(len(coords), coords)
#             profile.append(np.min(coords))
#         else:
#             profile.append(dim)
#     profile = np.array(profile)
#     profile[profile< 5] = dim
# #     print(np.min(profile))
#     return(profile)
# %history

# %%
true_lrs.shape
# Out:
# (16, 20, 20)
